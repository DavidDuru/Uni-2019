# %% [markdown]
# # Data Exploration with Python
#
# ## EXERCISE 1: Reading and Accessing Data
#
# ### Read the survey response data
#
# The `csv` module supports reading and writing of files in comma-separated values (CSV) and similar formats. We use `DictReader` since the first row of our survey responses file is a header. This produces a list of dictionaries, one dictionary per each individual survey response.
#
# A _dictionary_ is a data structure in Python that can hold key-value pairs, where we can lookup values by their key (typically a string).
#
# The `pprint` command below prints the dictionary corresponding the the first response.

# %%
import csv
import pprint
pp = pprint.PrettyPrinter(indent = 4)

f = csv.DictReader(open("programming_experience_survey_2019.csv"))

for row in f:
    pp.pprint(row)
    print()
    
test = 7823974923
# Out:
# OrderedDict([   ('respondent_id', '1'),
#                 ('submitted', '2019-03-07 13:00:38 UTC'),
#                 ('Tutorial Class', 'DATA2901 F08A'),
#                 ('Degree', 'Bachelor of Advanced Computing, 2nd year'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '2'),
#                 ('submitted', '2019-03-07 12:17:46 UTC'),
#                 (   'Tutorial Class',
#                     'Friday morning 10 p.m - 12 p.m madsen Computer Lab 226'),
#                 ('Degree', 'Computational Data Science Year 2'),
#                 ('Programming Experience', '2'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Sybase')])
#
# OrderedDict([   ('respondent_id', '3'),
#                 ('submitted', '2019-03-07 12:10:23 UTC'),
#                 ('Tutorial Class', 'F08A'),
#                 ('Degree', 'Bachelor of Science/Bachelor of Advanced Studies'),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 (   'Other Programming Languages Competency',
#                     'Matlab,R,Other (answer below in comment)'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 (   'Relational Databases Competency',
#                     'Other (answer as comment below)')])
#
# OrderedDict([   ('respondent_id', '4'),
#                 ('submitted', '2019-03-07 11:53:17 UTC'),
#                 ('Tutorial Class', 'F10A'),
#                 ('Degree', ''),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Basic understanding'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'C++,Java'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '5'),
#                 ('submitted', '2019-03-07 11:34:44 UTC'),
#                 ('Tutorial Class', 'SIT Lab 114'),
#                 ('Degree', 'Bachelor of Science'),
#                 ('Programming Experience', '2'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 (   'Other Programming Languages Competency',
#                     'Java,Javascript/ECMAScript,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '6'),
#                 ('submitted', '2019-03-07 11:28:21 UTC'),
#                 ('Tutorial Class', 'Friday 10 to 12'),
#                 (   'Degree',
#                     'Bachelor of Science and Bachelor of Advanced Studies. '
#                     'Second year.'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '7'),
#                 ('submitted', '2019-03-07 10:56:09 UTC'),
#                 ('Tutorial Class', 'on Friday'),
#                 ('Degree', ''),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', ''),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'SQLite')])
#
# OrderedDict([   ('respondent_id', '8'),
#                 ('submitted', '2019-03-07 10:53:01 UTC'),
#                 ('Tutorial Class', '2~4 pm Friday'),
#                 ('Degree', 'computer science, third year'),
#                 ('Programming Experience', '2'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', 'MySQL')])
#
# OrderedDict([   ('respondent_id', '9'),
#                 ('submitted', '2019-03-07 10:13:11 UTC'),
#                 ('Tutorial Class', 'Friday 10:00 AM SIT Lab 115'),
#                 ('Degree', 'Bachelor of Science Second Year'),
#                 ('Programming Experience', '2'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'C,Java,R,Visual Basic'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'Microsoft Access,MySQL')])
#
# OrderedDict([   ('respondent_id', '10'),
#                 ('submitted', '2019-03-07 09:53:24 UTC'),
#                 ('Tutorial Class', 'Friday 8:00am'),
#                 ('Degree', 'Bachelor of Science - 2nd year'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Matlab,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '11'),
#                 ('submitted', '2019-03-07 09:41:25 UTC'),
#                 ('Tutorial Class', 'at 8am on Friday.'),
#                 ('Degree', 'financial math'),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'C++'),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '12'),
#                 ('submitted', '2019-03-07 09:17:07 UTC'),
#                 ('Tutorial Class', '10 am adv'),
#                 ('Degree', 'BSc/BAdvStudies'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '13'),
#                 ('submitted', '2019-03-07 09:14:00 UTC'),
#                 ('Tutorial Class', 'DATA2001'),
#                 ('Degree', 'Computer Science, 2nd year'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'None'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C,Java'),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', 'Microsoft Access,Oracle')])
#
# OrderedDict([   ('respondent_id', '14'),
#                 ('submitted', '2019-03-07 08:12:18 UTC'),
#                 ('Tutorial Class', 'F12B'),
#                 ('Degree', 'B Engineering Honours/B Science 2nd Year'),
#                 ('Programming Experience', '0'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '15'),
#                 ('submitted', '2019-03-07 07:35:57 UTC'),
#                 ('Tutorial Class', 'F10A'),
#                 ('Degree', 'Bachelor of Science'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '16'),
#                 ('submitted', '2019-03-07 06:00:43 UTC'),
#                 ('Tutorial Class', 'Friday 12-2'),
#                 ('Degree', 'Bachelor of Science 2nd year'),
#                 ('Programming Experience', '3'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'C'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'SQLite')])
#
# OrderedDict([   ('respondent_id', '17'),
#                 ('submitted', '2019-03-07 05:49:14 UTC'),
#                 ('Tutorial Class', 'SIT LAB 114 (Friday 12-2pm)'),
#                 ('Degree', 'Bachelor of Advanced Computing'),
#                 ('Programming Experience', '3'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C#,Java,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '18'),
#                 ('submitted', '2019-03-07 05:16:45 UTC'),
#                 ('Tutorial Class', 'Friday 12-2 pm, Madsen Computer Lab 226'),
#                 (   'Degree',
#                     'B Science major in Information Systems and minor in Data '
#                     'Science'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java,R'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '19'),
#                 ('submitted', '2019-03-07 04:57:27 UTC'),
#                 ('Tutorial Class', 'DATA2001'),
#                 ('Degree', 'Computer Science'),
#                 ('Programming Experience', '4'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 (   'Other Programming Languages Competency',
#                     'C++,C#,Java,Matlab,R'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', 'MySQL')])
#
# OrderedDict([   ('respondent_id', '20'),
#                 ('submitted', '2019-03-07 04:26:30 UTC'),
#                 ('Tutorial Class', 'F10A'),
#                 (   'Degree',
#                     'Bachelor of Science/Bachelor of Advanced Studies '
#                     '(Advanced)'),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '21'),
#                 ('submitted', '2019-03-07 04:00:57 UTC'),
#                 ('Tutorial Class', 'Moday 10am madsen'),
#                 ('Degree', 'Advanced Computing 2'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '22'),
#                 ('submitted', '2019-03-07 03:24:33 UTC'),
#                 ('Tutorial Class', 'F10B'),
#                 ('Degree', 'Bachelor of Science'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '23'),
#                 ('submitted', '2019-03-07 03:01:35 UTC'),
#                 ('Tutorial Class', 'Friday, 12pm'),
#                 ('Degree', 'Bachelor of Advanced Computing, 2nd Year'),
#                 ('Programming Experience', '2'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java,Matlab,R'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', 'Microsoft Access,SQLite')])
#
# OrderedDict([   ('respondent_id', '24'),
#                 ('submitted', '2019-03-07 02:24:03 UTC'),
#                 ('Tutorial Class', 'Madsen computer lab 226, 12-2 PM'),
#                 ('Degree', 'Bachelor of Science, 2nd year'),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '25'),
#                 ('submitted', '2019-03-07 02:11:54 UTC'),
#                 ('Tutorial Class', 'SIT LAB 130A'),
#                 ('Degree', 'BCST Year 3'),
#                 ('Programming Experience', '2'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'C,Java,R'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '26'),
#                 ('submitted', '2019-03-07 01:58:17 UTC'),
#                 ('Tutorial Class', 'F08A'),
#                 ('Degree', 'Maths and Advanced Computing'),
#                 ('Programming Experience', '2'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java,Matlab,R'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '27'),
#                 ('submitted', '2019-03-07 01:38:12 UTC'),
#                 ('Tutorial Class', 'F10A'),
#                 ('Degree', 'Advanced Computing second year'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '28'),
#                 ('submitted', '2019-03-07 01:36:26 UTC'),
#                 ('Tutorial Class', '12:00-14:00 Madsen Computer lab R226'),
#                 ('Degree', '3rd year of B science'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', ''),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '29'),
#                 ('submitted', '2019-03-06 12:59:02 UTC'),
#                 ('Tutorial Class', 'SIT Lab 114'),
#                 ('Degree', 'computer science second year'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'None'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '30'),
#                 ('submitted', '2019-03-06 11:57:47 UTC'),
#                 ('Tutorial Class', '8 a.m. - 10a.m.'),
#                 ('Degree', "I'm in second year of Bachelor of science."),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java,Matlab,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '31'),
#                 ('submitted', '2019-03-06 11:52:00 UTC'),
#                 ('Tutorial Class', 'Yes.'),
#                 (   'Degree',
#                     'bachelor of software engineering, the second year of '
#                     'degree.'),
#                 ('Programming Experience', '2'),
#                 ('Experience in Python', 'Basic understanding'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C,Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'MySQL')])
#
# OrderedDict([   ('respondent_id', '32'),
#                 ('submitted', '2019-03-06 11:49:49 UTC'),
#                 ('Tutorial Class', 'yes'),
#                 (   'Degree',
#                     'bachelor of advanced computing major in computational '
#                     'data science'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Basic understanding'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 (   'Relational Databases Competency',
#                     'Other (answer as comment below)')])
#
# OrderedDict([   ('respondent_id', '33'),
#                 ('submitted', '2019-03-06 11:47:03 UTC'),
#                 ('Tutorial Class', 'F10C'),
#                 ('Degree', 'Bachelor of Engineering'),
#                 ('Programming Experience', '2'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '34'),
#                 ('submitted', '2019-03-06 11:22:48 UTC'),
#                 ('Tutorial Class', 'Friday 10am'),
#                 ('Degree', 'bachelor of science second year'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Matlab,R'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '35'),
#                 ('submitted', '2019-03-06 11:21:40 UTC'),
#                 ('Tutorial Class', '10am-12pm at SIT Lab 130A'),
#                 ('Degree', 'Bachelor of Science and Advanced Studies'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '36'),
#                 ('submitted', '2019-03-06 11:21:32 UTC'),
#                 ('Tutorial Class', 'yes'),
#                 ('Degree', 'The third year of bachelor.'),
#                 ('Programming Experience', '0'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C'),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '37'),
#                 ('submitted', '2019-03-06 10:51:23 UTC'),
#                 ('Tutorial Class', 'F10B'),
#                 ('Degree', 'second year in advanced computing degree'),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Basic understanding'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '38'),
#                 ('submitted', '2019-03-06 10:48:03 UTC'),
#                 ('Tutorial Class', 'Friday - 12pm to 2pm, in SIT Lab 115.'),
#                 (   'Degree',
#                     'Bachelor of Advanced Computing (Computational Data '
#                     'Science) and Bachelor of Commerce (Finance). I am in the '
#                     '2nd year of my degree.'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Have written complex Python programs already.'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java,Visual Basic'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'Microsoft Access,SQLite')])
#
# OrderedDict([   ('respondent_id', '39'),
#                 ('submitted', '2019-03-06 10:18:18 UTC'),
#                 ('Tutorial Class', 'Friday 10-12'),
#                 ('Degree', 'Advanced Science, Year 2'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 (   'Relational Databases Competency',
#                     'Other (answer as comment below)')])
#
# OrderedDict([   ('respondent_id', '40'),
#                 ('submitted', '2019-03-06 09:48:57 UTC'),
#                 (   'Tutorial Class',
#                     'Thursday 2 p.m. to 3 p.m. in Gunn Seminar Room 648.'),
#                 ('Degree', 'Second year of undergraduate.'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'Matlab,R,Other (answer below in comment)'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '41'),
#                 ('submitted', '2019-03-06 09:47:08 UTC'),
#                 ('Tutorial Class', 'Friday 12-2pm'),
#                 ('Degree', 'Bachelor of advanced computing. 2nd year.'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '42'),
#                 ('submitted', '2019-03-06 08:02:47 UTC'),
#                 ('Tutorial Class', 'STAT2011, DATA2001, QBUS2810, QBUS3310'),
#                 ('Degree', 'YEAR2'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'Javascript/ECMAScript'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '43'),
#                 ('submitted', '2019-03-06 07:55:16 UTC'),
#                 ('Tutorial Class', 'Friday 10-12pm'),
#                 ('Degree', 'Bachelor of Science'),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '44'),
#                 ('submitted', '2019-03-06 07:19:33 UTC'),
#                 ('Tutorial Class', 'Friday 4pm - 6pm SIT lab 115'),
#                 ('Degree', 'Bachelor of Science (Computer Science)'),
#                 ('Programming Experience', '2'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'Java,Javascript/ECMAScript'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 ('Relational Databases Competency', 'MongoDB,PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '45'),
#                 ('submitted', '2019-03-06 06:23:53 UTC'),
#                 ('Tutorial Class', 'F10A'),
#                 (   'Degree',
#                     'I am a second year student majoring in data science under '
#                     'bachelor of science.'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '46'),
#                 ('submitted', '2019-03-06 06:22:17 UTC'),
#                 ('Tutorial Class', 'F14A, Friday 2-4pm'),
#                 ('Degree', 'B Advanced Computing 1st year'),
#                 ('Programming Experience', '0.5'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '47'),
#                 ('submitted', '2019-03-06 06:07:09 UTC'),
#                 ('Tutorial Class', 'DATA2901 10AM-12PM'),
#                 (   'Degree',
#                     'Bachelor of Computer Science and Technology 4th year.'),
#                 ('Programming Experience', '3'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'C,C++,Java'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 ('Relational Databases Competency', 'MySQL,PostgreSQL,SQLite')])
#
# OrderedDict([   ('respondent_id', '48'),
#                 ('submitted', '2019-03-06 05:43:10 UTC'),
#                 ('Tutorial Class', 'F10A'),
#                 (   'Degree',
#                     'Bachelor of Advanced Computing and Bachelor of Commerce, '
#                     'second year.'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '49'),
#                 ('submitted', '2019-03-06 05:37:01 UTC'),
#                 (   'Tutorial Class',
#                     '[Friday 4-6 SIT Lab 115] '
#                     '(https://web.timetable.usyd.edu.au/examVenueDetails.jsp?venueAlias=J12.115)'),
#                 ('Degree', 'Data Science, second year'),
#                 ('Programming Experience', '2'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 (   'Other Programming Languages Competency',
#                     'C,Java,Javascript/ECMAScript,R'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'Microsoft SQL Server')])
#
# OrderedDict([   ('respondent_id', '50'),
#                 ('submitted', '2019-03-06 05:36:50 UTC'),
#                 ('Tutorial Class', 'Data 2001'),
#                 ('Degree', 'Advanced Computing Second Year'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '51'),
#                 ('submitted', '2019-03-06 05:35:00 UTC'),
#                 ('Tutorial Class', ''),
#                 ('Degree', ''),
#                 ('Programming Experience', ''),
#                 ('Experience in Python', ''),
#                 ('Used Jupyter Notebooks', ''),
#                 ('Other Programming Languages Competency', ''),
#                 ('SQL Competency', ''),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '52'),
#                 ('submitted', '2019-03-06 05:28:40 UTC'),
#                 ('Tutorial Class', ''),
#                 ('Degree', ''),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Basic understanding'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '53'),
#                 ('submitted', '2019-03-06 05:11:02 UTC'),
#                 ('Tutorial Class', 'F14B'),
#                 ('Degree', 'Bachelor of Advanced Computing 2nd year'),
#                 ('Programming Experience', '2'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '54'),
#                 ('submitted', '2019-03-06 05:02:56 UTC'),
#                 ('Tutorial Class', 'yes'),
#                 ('Degree', 'first year of USYD, third year of undergraduate'),
#                 ('Programming Experience', '3'),
#                 ('Experience in Python', 'Basic understanding'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C,C++,Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 (   'Relational Databases Competency',
#                     'Microsoft Access,Microsoft SQL '
#                     'Server,MySQL,SQLite,Sybase')])
#
# OrderedDict([   ('respondent_id', '55'),
#                 ('submitted', '2019-03-06 04:16:58 UTC'),
#                 ('Tutorial Class', 'SIT Lab 115 10:00am-12:00pm'),
#                 (   'Degree',
#                     'Bachelor of Commerce and Bachelor of Advanced Studies '
#                     'Year 2'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'Other (answer below in comment)'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Oracle')])
#
# OrderedDict([   ('respondent_id', '56'),
#                 ('submitted', '2019-03-06 04:06:06 UTC'),
#                 ('Tutorial Class', 'F08A'),
#                 ('Degree', 'B Adv. Computing, 2nd year'),
#                 ('Programming Experience', '7'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '57'),
#                 ('submitted', '2019-03-06 03:00:42 UTC'),
#                 ('Tutorial Class', 'F08A, SIT 115, 8-10am'),
#                 ('Degree', 'Bachelor of Science. Year 2'),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Basic understanding'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', ''),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '58'),
#                 ('submitted', '2019-03-06 02:57:17 UTC'),
#                 ('Tutorial Class', 'F10A'),
#                 (   'Degree',
#                     'Bachelor of Commerce and Advanced Studies - Second Year'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java,R'),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '59'),
#                 ('submitted', '2019-03-06 02:33:18 UTC'),
#                 ('Tutorial Class', 'Friday 8a.m. to 10a.m.'),
#                 ('Degree', 'Undergraduate. First year, second semester.'),
#                 ('Programming Experience', '0.5'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 (   'Relational Databases Competency',
#                     'Microsoft Access,Microsoft SQL Server')])
#
# OrderedDict([   ('respondent_id', '60'),
#                 ('submitted', '2019-03-06 00:47:03 UTC'),
#                 ('Tutorial Class', 'Fri 8am-10am'),
#                 ('Degree', 'Bachelor of Science, 2nd year'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 (   'Other Programming Languages Competency',
#                     'C,Java,Javascript/ECMAScript'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '61'),
#                 ('submitted', '2019-03-06 00:42:58 UTC'),
#                 ('Tutorial Class', 'Friday 8-10 am SIT Lab 114'),
#                 ('Degree', 'Advanced Computing, second year\xa0'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C++,Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '62'),
#                 ('submitted', '2019-03-06 00:40:41 UTC'),
#                 ('Tutorial Class', 'Friday 8:00AM (DATA2901)'),
#                 ('Degree', 'Science/AdvancedStudies, 2nd Year.'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '63'),
#                 ('submitted', '2019-03-06 00:37:47 UTC'),
#                 ('Tutorial Class', 'Friday 8:00 AM (Advanced)'),
#                 (   'Degree',
#                     'Bachelor of Science/Bachelor of Advanced Studies '
#                     '(Advanced)'),
#                 ('Programming Experience', '3'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'Javascript/ECMAScript,R'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '64'),
#                 ('submitted', '2019-03-06 00:35:48 UTC'),
#                 ('Tutorial Class', 'Friday 8am'),
#                 (   'Degree',
#                     'Second Year, Bachelor of Science (with Dalyell Scholars), '
#                     'majoring in Mathematics and Data Science.'),
#                 ('Programming Experience', '2'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java,R'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '65'),
#                 ('submitted', '2019-03-06 00:24:38 UTC'),
#                 ('Tutorial Class', 'Yes'),
#                 (   'Degree',
#                     'Major in Computer science, minor in data analytics. 1st '
#                     'year sem 2'),
#                 ('Programming Experience', '0.5'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Oracle')])
#
# OrderedDict([   ('respondent_id', '66'),
#                 ('submitted', '2019-03-06 00:24:33 UTC'),
#                 ('Tutorial Class', 'Friday 10am Madsen 226'),
#                 (   'Degree',
#                     'Bachelor Science, (Computer Science, Data Science) 2nd '
#                     'Year'),
#                 ('Programming Experience', '7'),
#                 (   'Experience in Python',
#                     'Have written complex Python programs already.'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'C#,Java,R,Visual Basic'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 (   'Relational Databases Competency',
#                     'Microsoft Access,Microsoft SQL Server,MySQL,SQLite')])
#
# OrderedDict([   ('respondent_id', '67'),
#                 ('submitted', '2019-03-06 00:16:46 UTC'),
#                 ('Tutorial Class', ''),
#                 ('Degree', ''),
#                 ('Programming Experience', '5'),
#                 (   'Experience in Python',
#                     'Have written complex Python programs already.'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C,C++,Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '68'),
#                 ('submitted', '2019-03-06 00:10:58 UTC'),
#                 ('Tutorial Class', 'F10A'),
#                 ('Degree', 'Advanced Computing / Commerce'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', 'SQLite')])
#
# OrderedDict([   ('respondent_id', '69'),
#                 ('submitted', '2019-03-06 00:02:33 UTC'),
#                 ('Tutorial Class', 'Fridays 12pm in SIT 115'),
#                 (   'Degree',
#                     'Bachelor of Science (Major Maths and Data Science), 2nd '
#                     'year'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'C++,Matlab,R'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'MySQL')])
#
# OrderedDict([   ('respondent_id', '70'),
#                 ('submitted', '2019-03-06 00:02:19 UTC'),
#                 ('Tutorial Class', 'Friday: 10am - 12 noon'),
#                 ('Degree', '1st year, Advanced Computing'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Basic understanding'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'C,Java'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'SQLite')])
#
# OrderedDict([   ('respondent_id', '71'),
#                 ('submitted', '2019-03-06 00:00:52 UTC'),
#                 ('Tutorial Class', '10am - 12pm Friday'),
#                 ('Degree', 'B Sci - 2nd Year'),
#                 ('Programming Experience', '2'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '72'),
#                 ('submitted', '2019-03-05 23:53:41 UTC'),
#                 ('Tutorial Class', 'Friday 1600'),
#                 ('Degree', 'Advanced Computing, year 2'),
#                 ('Programming Experience', '3'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'C,Java,R'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 ('Relational Databases Competency', 'MySQL,SQLite')])
#
# OrderedDict([   ('respondent_id', '73'),
# ...
#                 ('submitted', '2019-03-05 23:25:44 UTC'),
#                 ('Tutorial Class', 'Friday 4-6'),
#                 ('Degree', ''),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '77'),
#                 ('submitted', '2019-03-05 23:25:20 UTC'),
#                 ('Tutorial Class', 'SIT 115'),
#                 ('Degree', 'data science 2nd year'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C++,Java,Matlab,R'),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', 'Oracle')])
#
# OrderedDict([   ('respondent_id', '78'),
#                 ('submitted', '2019-03-05 23:23:22 UTC'),
#                 ('Tutorial Class', 'Friday 10am to 12pm SIT 115'),
#                 ('Degree', 'Advanced Computing, year 2'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'R,Other (answer below in comment)'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 (   'Relational Databases Competency',
#                     'Microsoft SQL Server,PostgreSQL,Other (answer as comment '
#                     'below)')])
#
# OrderedDict([   ('respondent_id', '79'),
#                 ('submitted', '2019-03-05 23:22:59 UTC'),
#                 (   'Tutorial Class',
#                     'DATA2901 Laboratory, Friday 10 a.m. to 12 p.m.'),
#                 ('Degree', 'Advanced Computing, 2nd Year'),
#                 ('Programming Experience', '6'),
#                 (   'Experience in Python',
#                     'Have written complex Python programs already.'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 (   'Other Programming Languages Competency',
#                     'Java,Other (answer below in comment)'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '80'),
#                 ('submitted', '2019-03-05 23:22:12 UTC'),
#                 ('Tutorial Class', 'Sit115'),
#                 ('Degree', 'Bachelor of science'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 (   'Relational Databases Competency',
#                     'Microsoft SQL Server,SQLite')])
#
# OrderedDict([   ('respondent_id', '81'),
#                 ('submitted', '2019-03-05 23:19:25 UTC'),
#                 ('Tutorial Class', 'Friday 10-12'),
#                 ('Degree', 'Year 2 in Biomedical Engineering major in IT'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Matlab,R'),
#                 ('SQL Competency', 'Never heard of SQL.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '82'),
#                 ('submitted', '2019-03-05 23:13:03 UTC'),
#                 ('Tutorial Class', 'F10A'),
#                 ('Degree', 'Bachelor of advanced computing'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'C,Java'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Oracle,SQLite')])
#
# OrderedDict([   ('respondent_id', '83'),
#                 ('submitted', '2019-03-05 23:12:08 UTC'),
#                 ('Tutorial Class', 'Friday 12pm-2pm, SIT 114'),
#                 (   'Degree',
#                     '2nd year bachelor of advanced computing. Majoring in Data '
#                     'Science'),
#                 ('Programming Experience', '1.5'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java,R'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '84'),
#                 ('submitted', '2019-03-05 23:11:10 UTC'),
#                 ('Tutorial Class', 'friday 10 a.m.'),
#                 ('Degree', 'B of science'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'MySQL')])
#
# OrderedDict([   ('respondent_id', '85'),
#                 ('submitted', '2019-03-05 23:11:10 UTC'),
#                 ('Tutorial Class', 'Friday 10-12pm SIT130A'),
#                 (   'Degree',
#                     'Bachelor of Science (Adv) / Bachelor of Advanced Studies, '
#                     '3rd year'),
#                 ('Programming Experience', '1'),
#                 ('Experience in Python', 'Basic understanding'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java,Matlab,R'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'MySQL,PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '86'),
#                 ('submitted', '2019-03-05 23:10:26 UTC'),
#                 ('Tutorial Class', ''),
#                 ('Degree', ''),
#                 ('Programming Experience', ''),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'Java,Javascript/ECMAScript,Matlab,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', 'Microsoft Access')])
#
# OrderedDict([   ('respondent_id', '87'),
#                 ('submitted', '2019-03-05 23:08:48 UTC'),
#                 ('Tutorial Class', 'data2901'),
#                 ('Degree', ''),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'C,Java,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '88'),
#                 ('submitted', '2019-03-05 23:08:36 UTC'),
#                 ('Tutorial Class', 'Friday 10am Madsen Computer Lab 226'),
#                 ('Degree', 'Advanced Computing, year 2'),
#                 ('Programming Experience', '1.5'),
#                 (   'Experience in Python',
#                     'Have written complex Python programs already.'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 (   'Relational Databases Competency',
#                     'Microsoft Access,Microsoft SQL '
#                     'Server,MongoDB,PostgreSQL,SQLite')])
#
# OrderedDict([   ('respondent_id', '89'),
#                 ('submitted', '2019-03-05 23:05:52 UTC'),
#                 ('Tutorial Class', 'F10B'),
#                 ('Degree', '2nd year, Bachelor of Science'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '90'),
#                 ('submitted', '2019-03-05 22:31:39 UTC'),
#                 ('Tutorial Class', 'F14A'),
#                 ('Degree', 'Bachelor of advanced computing'),
#                 ('Programming Experience', '2'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'MySQL')])
#
# OrderedDict([   ('respondent_id', '91'),
#                 ('submitted', '2019-03-05 22:30:00 UTC'),
#                 ('Tutorial Class', 'F08A'),
#                 ('Degree', '3rd year in computer science'),
#                 ('Programming Experience', '2'),
#                 ('Experience in Python', 'Written some simple Python programs'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 (   'Other Programming Languages Competency',
#                     'C,Java,Javascript/ECMAScript'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 ('Relational Databases Competency', 'PostgreSQL,SQLite')])
#
# OrderedDict([   ('respondent_id', '92'),
#                 ('submitted', '2019-03-05 22:21:57 UTC'),
#                 ('Tutorial Class', 'F08A'),
#                 (   'Degree',
#                     'bachelor of biomedical engineering honour 3rd year'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Matlab,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 (   'Relational Databases Competency',
#                     'Other (answer as comment below)')])
#
# OrderedDict([   ('respondent_id', '93'),
#                 ('submitted', '2019-03-05 22:12:59 UTC'),
#                 ('Tutorial Class', 'FRIDAY 10am - 12 am SIT 115'),
#                 ('Degree', 'Project Management software'),
#                 ('Programming Experience', '2'),
#                 ('Experience in Python', 'None'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java,Matlab,R'),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '94'),
#                 ('submitted', '2019-03-05 22:12:37 UTC'),
#                 ('Tutorial Class', 'Friday, 10-12, SIT lab 115'),
#                 ('Degree', 'Bachelor of Advanced Computing, year 2'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Have written complex Python programs already.'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 ('Other Programming Languages Competency', 'Java,Matlab,R'),
#                 ('SQL Competency', 'Heard of it, but never used it.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '95'),
#                 ('submitted', '2019-03-05 21:53:51 UTC'),
#                 ('Tutorial Class', 'F08A (advanced)'),
#                 (   'Degree',
#                     'B Commerce/B Advanced Studies, 2nd year first semester'),
#                 ('Programming Experience', '4'),
#                 (   'Experience in Python',
#                     'Have written complex Python programs already.'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 (   'Other Programming Languages Competency',
#                     'Javascript/ECMAScript,R'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '96'),
#                 ('submitted', '2019-03-05 21:15:54 UTC'),
#                 ('Tutorial Class', 'Friday 4pm-6pm in SIT lab 115'),
#                 (   'Degree',
#                     'Bachelor of Science (Computer Science), currently in 2nd '
#                     'year.'),
#                 ('Programming Experience', '2'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', 'Java'),
#                 (   'SQL Competency',
#                     'Can already create tables and write complex SQL queries.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])
#
# OrderedDict([   ('respondent_id', '97'),
#                 ('submitted', '2019-03-05 19:58:54 UTC'),
#                 ('Tutorial Class', 'Friday 8am'),
#                 (   'Degree',
#                     'BSc (Physiology), sorta 3rd year (66th year studying part '
#                     'time)'),
#                 ('Programming Experience', '1'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'Yes'),
#                 ('Other Programming Languages Competency', ''),
#                 ('SQL Competency', 'Can interpret some SQL statements.'),
#                 ('Relational Databases Competency', '')])
#
# OrderedDict([   ('respondent_id', '98'),
#                 ('submitted', '2019-03-05 15:41:05 UTC'),
#                 ('Tutorial Class', 'Friday, 4pm SIT Lab 115.'),
#                 ('Degree', 'Computer Science and Technology (3 yr FTE)'),
#                 ('Programming Experience', '3'),
#                 (   'Experience in Python',
#                     'Competent Python programmer (familiar with eg. functions '
#                     'and classes)'),
#                 ('Used Jupyter Notebooks', 'No'),
#                 (   'Other Programming Languages Competency',
#                     'C,Java,Visual Basic,Other (answer below in comment)'),
#                 ('SQL Competency', 'Written some SQL queries already.'),
#                 ('Relational Databases Competency', 'PostgreSQL')])

# %% [markdown]
# ### Let's define constants for dictionary keys
#
# Before moving on, let's define constants for the keys of this dictionary that will make it a bit easier to use. In our case, the keys are simply the questions from our survey in Week 1.

# %%
print(test)
# Out:
# 7823974923

# %% [markdown]
# ### Accessing data values
#
# This allows us to access cells in a row using the column name as a key. For example, the following prints the number of years professional experience for the first respondent. Note that the csv module reads all values as strings.

# %%
k = set(row.keys())
print(k)
# Out:
# {'Relational Databases Competency', 'Degree', 'Experience in Python', 'respondent_id', 'submitted', 'SQL Competency', 'Programming Experience', 'Other Programming Languages Competency', 'Tutorial Class', 'Used Jupyter Notebooks'}

# %% [markdown]
# ## TODO for you
# Display the 9th, 15th, 31th and the 2nd last record of the dictionary (hint: follow the python codes in the lecture slides).

# %%
# TODO For you
raise NotImplementedError

# %% [markdown]
# ## EXERCISE 2: Data Cleaning and Conversion
#
# ### 2a) Encoding Python Programming Experience
#
# Write some Python code that considers the provided levels of Python experience and encodes each level to a corresponding integer number from 1 to 5.

# %%
# TODO For you
raise NotImplementedError

# %% [markdown]
# ### 2b)  Counting ProgLang Competencies
#
# Define the cardinality for each respondent by considering responses in regards to their experience described in ’other programming languages competency’. For example, a response like ’C#, Java, Javascript/ECMAScript, Matlab’ = 4, ’Matlab,R’ = 2, ... likewise.

# %%
# TODO For you
raise NotImplementedError

# %% [markdown]
# ### 2c) Counting RDBMS Competencies
#
# Define the cardinality for each respondent by considering responses in regards to their RDBMS experience described in the 'Relational Database Competency’ column (e.g., ’Microsoft Access, Microsoft SQL Server, Oracle, PostgreSQL’ = 4, ’MySQL, PostgreSQL’ = 2). Define a new list as well and name it as ’Number of SQL Competencies’.

# %%
# TODO For you
raise NotImplementedError

# %% [markdown]
# ### 2d) Encoding SQL Experience
#
# Encode the column ’SQL Competency’ into integer levels of a five-level Likert scale

# %%
# TODO For you
raise NotImplementedError

# %% [markdown]
# ### 2e) Cleaning Tutorial Classes Answers
#
# Define a Python method to clean the ’Tutorial class’ column by analysing the texts in cells as follows (it will be written in all kinds of variants, tae the following as a general mapping):
#
# - SIT Lab 115 (Friday 8am-10am) = F08A
# - SIT Lab 114 advanced (Friday 8am-10am) = F08ADV
# - SIT Lab 115 (Friday 10am-12pm) = F10A
# - Madsen Lab (Friday 10am-12pm) = F10B
# - SIT Lab 114 advanced (Friday 10am-12pm) = F10ADV
# - SIT Lab 115 (Friday 12-2pm) = F12A
# - SIT Lab 114 (Friday 12-2pm) = F12B
# - Madsen Lab(Friday 12-2pm) = F12C
# - SIT Lab 115 (Friday 2-4pm) = F14A
# - SIT Lab 130A (Friday 2-4pm) = F14B
# - SIT Lab 115 (Friday 4-6pm) = F16A
#
# All strings need to be cleaned and converted such that this column contains only the given (F08A, F10A, F12A, ..., F16A) codes. All values which do not fit into this pattern (e.g. a single ”Yes” answer) should be convert to ’NA’.

# %%
# TODO For you
raise NotImplementedError

# %% [markdown]
# ## EXERCISE 3: Analysing Date and Time
#
# Display the time component of the ’Submitted’ column by ignoring the date part for the first and last 10 records (rows).
# For example, 2018-03-13 23:41:57 should be interpreted as
# Hour: 23
# Minute: 41 Second: 57

# %%
# TODO For you
raise NotImplementedError

# %% [markdown]
# ## EXERCISE 4: Data Visualisations
#
# ### 4(a) Frequency Plot of Programming Experience
# Show a frequency plot of the 'Programming Experience' as given by the respondents. In this plot, the x-axis should contain the experience in years (1, 2, 3, 4, 5...) and y-axis should contain how many respondents have programming experience of the corresponding duration.

# %%
# TODO For you
raise NotImplementedError

# %% [markdown]
# ### 4(b) Boxplot of Number of Languages Competencies and Number of SQL Competencies
#
# how box plots of the two lickert-scale lists you defined above ('Number of Languages Competencies' and 'Number of SQL Competencies')

# %%
# TODO For you
raise NotImplementedError

# %% [markdown]
# ### 4(c) Optional and advanced: Histogram of Number of Students per Degree
#
# Visualize the number students per degree (e.g., how many students are enrolled in computer science degree) as a histogram plot.

# %%
# TODO For you
raise NotImplementedError
